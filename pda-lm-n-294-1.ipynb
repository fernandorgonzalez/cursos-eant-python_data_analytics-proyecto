# %%
#Importamos librerías
import folium
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#Archivo donde tomamos el set de datos para bicicletas luego de su limpieza y normalización con la notebook bicicletas.ipynb
input_file_name_bicicletas = "https://github.com/fernandorgonzalez/cursos-eant-python_data_analytics-proyecto/blob/main/bicicletas.xlsx?raw=true"
input_sheet_name_bicicletas = "bicicletas"

# %%
#Archivo donde tomamos el set de datos para contaminantes luego de su limpieza y normalización con la notebook contaminantes.ipynb
input_file_name_contaminantes = "https://github.com/fernandorgonzalez/cursos-eant-python_data_analytics-proyecto/blob/main/contaminantes.xlsx?raw=true"
input_sheet_name_contaminantes = "contaminantes"

# %%
#Archivo donde tomamos el set de datos para covid luego de su limpieza y normalización con la notebook covid.ipynb
input_file_name_covid = "https://github.com/fernandorgonzalez/cursos-eant-python_data_analytics-proyecto/blob/main/covid.xlsx?raw=true"
input_sheet_name_covid = "covid"

# %%
#Archivo donde tomamos el set de datos correspondiente a las estaciones ambientales
input_file_name_estaciones = 'https://cdn.buenosaires.gob.ar/datosabiertos/datasets/calidad-de-aire/estaciones-ambientales.xlsx'
input_sheet_name_estaciones = "Sheet1"

# %%
#Archivo donde tomamos el set de datos para subte luego de su limpieza y normalización con la notebook subte.ipynb
input_file_name_subte = "https://github.com/fernandorgonzalez/cursos-eant-python_data_analytics-proyecto/blob/main/subte.xlsx?raw=true"
input_sheet_name_subte = "subte"

# %%
#Archivo donde tomamos el set de datos para vehículos luego de su limpieza y normalización con la notebook vehiculos.ipynb
input_file_name_vehiculos = "https://github.com/fernandorgonzalez/cursos-eant-python_data_analytics-proyecto/blob/main/vehiculos.xlsx?raw=true"
input_sheet_name_vehiculos = "vehiculos"

# %%
#Carga de dataframe para bicicletas
df_bicicletas = pd.read_excel(input_file_name_bicicletas, sheet_name = input_sheet_name_bicicletas)
df_bicicletas
# Out:
#      Año  Mes        Tipo   Total  Intervalo Diciembre Vs Enero
# 0   2020    1  Bicicletas  159233          5             +100 %
# 1   2020    2  Bicicletas  116965          4             +100 %
# 2   2020    3  Bicicletas   52951          2             +100 %
# 3   2020    4  Bicicletas       0          1             +100 %
# 4   2020    5  Bicicletas   20235          1             +100 %
# 5   2020    6  Bicicletas   69707          3             +100 %
# 6   2020    7  Bicicletas   98328          3             +100 %
# 7   2020    8  Bicicletas  248180          8             +100 %
# 8   2020    9  Bicicletas  273719          9             +100 %
# 9   2020   10  Bicicletas  323130         10             +100 %
# 10  2020   11  Bicicletas  332410         10             +100 %
# 11  2020   12  Bicicletas  308087         10             +100 %

# %%
#Carga de dataframe para contaminantes
df_contaminantes = pd.read_excel(input_file_name_contaminantes, sheet_name = input_sheet_name_contaminantes)
df_contaminantes
# Out:
#      Año  Mes           Tipo  Total  Intervalo Diciembre Vs Enero
# 0   2020    1  Contaminantes  21.75          7              -28 %
# 1   2020    2  Contaminantes  20.60          6              -28 %
# 2   2020    3  Contaminantes  13.68          2              -28 %
# 3   2020    4  Contaminantes  11.60          1              -28 %
# 4   2020    5  Contaminantes  18.57          5              -28 %
# 5   2020    6  Contaminantes  18.03          4              -28 %
# 6   2020    7  Contaminantes  20.60          6              -28 %
# 7   2020    8  Contaminantes  27.74         10              -28 %
# 8   2020    9  Contaminantes  19.37          5              -28 %
# 9   2020   10  Contaminantes  16.52          4              -28 %
# 10  2020   11  Contaminantes  17.89          4              -28 %
# 11  2020   12  Contaminantes  18.88          5              -28 %

# %%
#Carga de dataframe para Casos de Covid
df_covid = pd.read_excel(input_file_name_covid, sheet_name = input_sheet_name_covid)
df_covid
# Out:
#      Año  Mes            Tipo  Total  Intervalo Diciembre Vs Enero
# 0   2020    1  Casos de Covid     97          1             +900 %
# 1   2020    2  Casos de Covid     30          1             +900 %
# 2   2020    3  Casos de Covid    643          1             +900 %
# 3   2020    4  Casos de Covid   4245          1             +900 %
# 4   2020    5  Casos de Covid  13178          2             +900 %
# 5   2020    6  Casos de Covid  31192          4             +900 %
# 6   2020    7  Casos de Covid  49358          7             +900 %
# 7   2020    8  Casos de Covid  57396          8             +900 %
# 8   2020    9  Casos de Covid  52179          7             +900 %
# 9   2020   10  Casos de Covid  52403          7             +900 %
# 10  2020   11  Casos de Covid  44221          6             +900 %
# 11  2020   12  Casos de Covid  78714         10             +900 %

# %%
#Carga de dataframe para estaciones ambientales
df_estaciones = pd.read_excel(input_file_name_estaciones, sheet_name = input_sheet_name_estaciones)
df_estaciones
# Out:
#                    X                  Y      NOMBRE  \
# 0  -58,3663735070165  -34,6252584813295     LA BOCA
# 1  -58,4320717652753  -34,6066080998154  CENTENARIO
# 2   -58,391552893462  -34,5995643433432     CORDOBA
# 3  -58,4053598727298  -34,5834529467442     PALERMO
#
#                          DIRECCION INICIO_DE_ACTIVIDAD  \
# 0                   AV. BRASIL 100          01/05/2009
# 1                RAMOS MEJÃA 800           01/01/2005
# 2   AV. CORDOBA Y RODRIGUEZ PEÃA           01/05/2009
# 3  AV. LAS HERAS Y ORTIZ DE OCAMPO          01/01/2002
#
#                                ZONA_DE_EMPLAZAMIENTO      EN_RED  \
# 0  ZONA MIXTA CON FLUJO VEHICULAR MEDIO-BAJO E IN...  01/09/2009
# 1  (PARQUE CENTENARIO) AREA RESIDENCIAL-COMERCIAL...         NaN
# 2  AREA RESIDENCIAL-COMERCIAL CON FLUJO VEHICULAR...         NaN
# 3  ESTACION DESACTIVADA DESDE 30/06/2010 AREA RES...         NaN
#
#        PARAMETROS_MEDIDOS                  CALLE  ALTURA             CRUCE  \
# 0  CO, NO, NO2, NOX, PM10             BRASIL AV.   100.0               NaN
# 1  CO, NO, NO2, NOX, PM10            RAMOS MEJIA   800.0               NaN
# 2  CO, NO, NO2, NOX, PM10            CORDOBA AV.     NaN  RODRIGUEZ PEï¿½A
# 3  CO, NO, NO2, NOX, PM10  LAS HERAS GENERAL AV.     NaN   ORTIZ DE OCAMPO
#
#        CP       CPA
# 0  1063.0  C1063AAB
# 1  1405.0  C1405CAD
# 2     NaN       NaN
# 3     NaN       NaN

# %%
#Carga de dataframe para Subte
df_subte = pd.read_excel(input_file_name_subte, sheet_name = input_sheet_name_subte)
df_subte
# Out:
#      Año  Mes   Tipo     Total  Intervalo Diciembre Vs Enero
# 0   2020    1  Subte  14431260          9              -77 %
# 1   2020    2  Subte  14379523          9              -77 %
# 2   2020    3  Subte  16665570         10              -77 %
# 3   2020    4  Subte   2532868          1              -77 %
# 4   2020    5  Subte   2769479          1              -77 %
# 5   2020    6  Subte   3566230          1              -77 %
# 6   2020    7  Subte   3417198          1              -77 %
# 7   2020    8  Subte   3122951          1              -77 %
# 8   2020    9  Subte   3629713          1              -77 %
# 9   2020   10  Subte   4966696          2              -77 %
# 10  2020   11  Subte   3768015          1              -77 %
# 11  2020   12  Subte   4255468          2              -77 %

# %%
#Carga de dataframe para Vehículos
df_vehiculos = pd.read_excel(input_file_name_vehiculos, sheet_name = input_sheet_name_vehiculos)
df_vehiculos
# Out:
#      Año  Mes       Tipo   Total  Intervalo Diciembre Vs Enero
# 0   2020    1  Vehículos  248546         10              -10 %
# 1   2020    2  Vehículos  232209          9              -10 %
# 2   2020    3  Vehículos  197980          6              -10 %
# 3   2020    4  Vehículos  143191          1              -10 %
# 4   2020    5  Vehículos  171215          3              -10 %
# 5   2020    6  Vehículos  212227          7              -10 %
# 6   2020    7  Vehículos  209202          7              -10 %
# 7   2020    8  Vehículos  213511          7              -10 %
# 8   2020    9  Vehículos  219852          8              -10 %
# 9   2020   10  Vehículos  226641          8              -10 %
# 10  2020   11  Vehículos  222866          8              -10 %
# 11  2020   12  Vehículos  236303          9              -10 %

# %%
#Concatenamos los cuatro datasets
df = pd.concat([df_bicicletas,df_contaminantes,df_covid,df_subte,df_vehiculos]).reset_index(drop=True)
df
# Out:
#      Año  Mes            Tipo        Total  Intervalo Diciembre Vs Enero
# 0   2020    1      Bicicletas    159233.00          5             +100 %
# 1   2020    2      Bicicletas    116965.00          4             +100 %
# 2   2020    3      Bicicletas     52951.00          2             +100 %
# 3   2020    4      Bicicletas         0.00          1             +100 %
# 4   2020    5      Bicicletas     20235.00          1             +100 %
# 5   2020    6      Bicicletas     69707.00          3             +100 %
# 6   2020    7      Bicicletas     98328.00          3             +100 %
# 7   2020    8      Bicicletas    248180.00          8             +100 %
# 8   2020    9      Bicicletas    273719.00          9             +100 %
# 9   2020   10      Bicicletas    323130.00         10             +100 %
# 10  2020   11      Bicicletas    332410.00         10             +100 %
# 11  2020   12      Bicicletas    308087.00         10             +100 %
# 12  2020    1   Contaminantes        21.75          7              -28 %
# 13  2020    2   Contaminantes        20.60          6              -28 %
# 14  2020    3   Contaminantes        13.68          2              -28 %
# 15  2020    4   Contaminantes        11.60          1              -28 %
# 16  2020    5   Contaminantes        18.57          5              -28 %
# 17  2020    6   Contaminantes        18.03          4              -28 %
# 18  2020    7   Contaminantes        20.60          6              -28 %
# 19  2020    8   Contaminantes        27.74         10              -28 %
# 20  2020    9   Contaminantes        19.37          5              -28 %
# 21  2020   10   Contaminantes        16.52          4              -28 %
# 22  2020   11   Contaminantes        17.89          4              -28 %
# 23  2020   12   Contaminantes        18.88          5              -28 %
# 24  2020    1  Casos de Covid        97.00          1             +900 %
# 25  2020    2  Casos de Covid        30.00          1             +900 %
# 26  2020    3  Casos de Covid       643.00          1             +900 %
# 27  2020    4  Casos de Covid      4245.00          1             +900 %
# 28  2020    5  Casos de Covid     13178.00          2             +900 %
# 29  2020    6  Casos de Covid     31192.00          4             +900 %
# 30  2020    7  Casos de Covid     49358.00          7             +900 %
# 31  2020    8  Casos de Covid     57396.00          8             +900 %
# 32  2020    9  Casos de Covid     52179.00          7             +900 %
# 33  2020   10  Casos de Covid     52403.00          7             +900 %
# 34  2020   11  Casos de Covid     44221.00          6             +900 %
# 35  2020   12  Casos de Covid     78714.00         10             +900 %
# 36  2020    1           Subte  14431260.00          9              -77 %
# 37  2020    2           Subte  14379523.00          9              -77 %
# 38  2020    3           Subte  16665570.00         10              -77 %
# 39  2020    4           Subte   2532868.00          1              -77 %
# 40  2020    5           Subte   2769479.00          1              -77 %
# 41  2020    6           Subte   3566230.00          1              -77 %
# 42  2020    7           Subte   3417198.00          1              -77 %
# 43  2020    8           Subte   3122951.00          1              -77 %
# 44  2020    9           Subte   3629713.00          1              -77 %
# 45  2020   10           Subte   4966696.00          2              -77 %
# 46  2020   11           Subte   3768015.00          1              -77 %
# 47  2020   12           Subte   4255468.00          2              -77 %
# 48  2020    1       Vehículos    248546.00         10              -10 %
# 49  2020    2       Vehículos    232209.00          9              -10 %
# 50  2020    3       Vehículos    197980.00          6              -10 %
# 51  2020    4       Vehículos    143191.00          1              -10 %
# 52  2020    5       Vehículos    171215.00          3              -10 %
# 53  2020    6       Vehículos    212227.00          7              -10 %
# 54  2020    7       Vehículos    209202.00          7              -10 %
# 55  2020    8       Vehículos    213511.00          7              -10 %
# 56  2020    9       Vehículos    219852.00          8              -10 %
# 57  2020   10       Vehículos    226641.00          8              -10 %
# 58  2020   11       Vehículos    222866.00          8              -10 %
# 59  2020   12       Vehículos    236303.00          9              -10 %

# %%
#Previsualización de la paleta a utilizar para los meses del año
sns.color_palette('plasma',12)
# Out:
# [(0.21435, 0.016973, 0.599239),
#  (0.343925, 0.004991, 0.64471),
#  (0.46555, 0.004545, 0.660139),
#  (0.573632, 0.060028, 0.637349),
#  (0.674522, 0.147419, 0.578688),
#  (0.760264, 0.235976, 0.505794),
#  (0.830018, 0.320172, 0.437836),
#  (0.89325, 0.411048, 0.369768),
#  (0.944844, 0.507658, 0.302433),
#  (0.979233, 0.607532, 0.238013),
#  (0.994474, 0.722691, 0.174381),
#  (0.98119, 0.848329, 0.142279)]

# %%
#Definición de la paleta para los meses del año
paleta_meses = {}
for i in range(0,12):
    paleta_meses[i+1] = sns.color_palette('plasma',12)[i]
paleta_meses
# Out:
# {1: (0.21435, 0.016973, 0.599239),
#  2: (0.343925, 0.004991, 0.64471),
#  3: (0.46555, 0.004545, 0.660139),
#  4: (0.573632, 0.060028, 0.637349),
#  5: (0.674522, 0.147419, 0.578688),
#  6: (0.760264, 0.235976, 0.505794),
#  7: (0.830018, 0.320172, 0.437836),
#  8: (0.89325, 0.411048, 0.369768),
#  9: (0.944844, 0.507658, 0.302433),
#  10: (0.979233, 0.607532, 0.238013),
#  11: (0.994474, 0.722691, 0.174381),
#  12: (0.98119, 0.848329, 0.142279)}

# %%
paleta_comparacion = sns.color_palette('plasma',12)

# %%
#Visualización de los Casos de Covid
plt.figure(figsize=(10,7))
s = sns.barplot(data = df_covid,
            x = 'Mes',
            y = 'Total',
            palette = paleta_meses)
for p in s.patches:
    s.annotate(int(p.get_height()), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   xytext = (0, 9), 
                   textcoords = 'offset points',
                   weight="bold",color="#565656")
plt.title("Casos de Covid 2020", fontsize = 20,backgroundcolor="#565656",
  weight="bold",color="white",style="italic",loc="center",pad=30)
plt.xlabel('Mes',weight="bold",size=20,color="#565656")
plt.ylabel('Total',weight="bold",size=20,color="#565656")
plt.tick_params(labelsize=10,length=0)
plt.box(False)
plt.grid(linewidth=0.5,color="grey",linestyle="-.")
plt.show()

# %%
#Visualización de la estación Córdoba
lat = (df_estaciones.loc[:,'X'])
lat = [pd.to_numeric(i.replace(',','.')) for i in lat]
la_bocaX = lat[0]
centenarioX = lat[1]
cordobaX = lat[2]
palermoX = lat[3]

lon = df_estaciones.loc[:,'Y']
lon = [pd.to_numeric(i.replace(',','.')) for i in lon]
la_bocaY = lon[0]
centenarioY = lon[1]
cordobaY = lon[2]
palermoY = lon[3]

lon =  -58.38162
lat = -34.60376


m = folium.Map(location = [lat, lon], zoom_start = 10)
folium.TileLayer(tiles= "OpenStreetMap").add_to(m)
folium.TileLayer(tiles= "Stamen Terrain").add_to(m)
folium.TileLayer(tiles= "Stamen Toner").add_to(m)
folium.TileLayer(tiles= "Stamen Watercolor").add_to(m)
folium.TileLayer(tiles= "CartoDB Dark_Matter").add_to(m)
folium.LayerControl().add_to(m)
folium.Marker(location= [cordobaY,cordobaX], popup= 'Estación Ambiental Córdoba').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3192b7217b84428aa40cb11568234550%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3192b7217b84428aa40cb11568234550%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3192b7217b84428aa40cb11568234550%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3192b7217b84428aa40cb11568234550%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-34.60376%2C%20-58.38162%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
#Visualización de los Contaminantes
plt.figure(figsize=(10,7))
s = sns.barplot(data = df_contaminantes,
            x = 'Mes',
            y = 'Total',
            palette = paleta_meses)
for p in s.patches:
    s.annotate(p.get_height(), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   xytext = (0, 9), 
                   textcoords = 'offset points',
                   weight="bold",color="#565656")
plt.title("Contaminantes 2020 (" + df_contaminantes.iloc[0][5] + ")", fontsize = 20,backgroundcolor="#565656",
  weight="bold",color="white",style="italic",loc="center",pad=30)
plt.xlabel('Mes',weight="bold",size=20,color="#565656")
plt.ylabel('Total',weight="bold",size=20,color="#565656")
plt.tick_params(labelsize=10,length=0)
plt.box(False)
plt.grid(linewidth=0.5,color="grey",linestyle="-.")
plt.show()

# %%
#Visualización de los Viajes en Bicicleta
plt.figure(figsize=(10,7))
s = sns.barplot(data = df_bicicletas,
            x = 'Mes',
            y = 'Total',
            palette = paleta_meses)
for p in s.patches:
    s.annotate(str(int(p.get_height()/1000)) + 'K', 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   xytext = (0, 9), 
                   textcoords = 'offset points',
                   weight="bold",color="#565656")
plt.title("Viajes en Bicicleta 2020 (" + df_bicicletas.iloc[0][5] + ")", fontsize = 20,backgroundcolor="#565656",
  weight="bold",color="white",style="italic",loc="center",pad=30)
plt.xlabel('Mes',weight="bold",size=20,color="#565656")
plt.ylabel('Total',weight="bold",size=20,color="#565656")
plt.tick_params(labelsize=10,length=0)
plt.box(False)
plt.grid(linewidth=0.5,color="grey",linestyle="-.")
plt.show()

# %%
#Visualización de los Viajes en Subte
plt.figure(figsize=(10,7))
s = sns.barplot(data = df_subte,
            x = 'Mes',
            y = 'Total',
            palette = paleta_meses)
for p in s.patches:
    s.annotate(str(int(p.get_height()/1000)) + 'K', 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   xytext = (0, 9), 
                   textcoords = 'offset points',
                   weight="bold",color="#565656")
plt.title("Viajes en Subte 2020 (" + df_subte.iloc[0][5] + ")", fontsize = 20,backgroundcolor="#565656",
  weight="bold",color="white",style="italic",loc="center",pad=30)
plt.xlabel('Mes',weight="bold",size=20,color="#565656")
plt.ylabel('Total',weight="bold",size=20,color="#565656")
plt.tick_params(labelsize=10,length=0)
plt.box(False)
plt.grid(linewidth=0.5,color="grey",linestyle="-.")
plt.show()

# %%
#Visualización de los Viajes en Vehiculos
plt.figure(figsize=(10,7))
s = sns.barplot(data = df_vehiculos,
            x = 'Mes',
            y = 'Total',
            palette = paleta_meses)
for p in s.patches:
    s.annotate(str(int(p.get_height()/1000)) + 'K', 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   xytext = (0, 9), 
                   textcoords = 'offset points',
                   weight="bold",color="#565656")
plt.title("Viajes en Vehículos 2020 (" + df_vehiculos.iloc[0][5] + ")", fontsize = 20,backgroundcolor="#565656",
  weight="bold",color="white",style="italic",loc="center",pad=30)
plt.xlabel('Mes',weight="bold",size=20,color="#565656")
plt.ylabel('Total',weight="bold",size=20,color="#565656")
plt.tick_params(labelsize=10,length=0)
plt.box(False)
plt.grid(linewidth=0.5,color="grey",linestyle="-.")
plt.show()

# %%
#Visualización de la comparación entre los Casos de Covid, Contaminantes y Viajes en Tranporte
plt.figure(figsize=(15,8))

#Estilo de la gráfica
plt.style.use('fast')

#Casos de Covid: generación de Barplot
plt.bar(df_covid.Mes,df_covid.Intervalo,color=paleta_comparacion,label='Casos de Covid')

#Contaminantes: generación de Lineplot
plt.plot(df_contaminantes.Mes,df_contaminantes.Intervalo,color='#E30049',linestyle='--',marker='d',markersize=12,linewidth=5,label='Contaminantes')

#Bicicletas: generación de Lineplot
plt.plot(df_bicicletas.Mes,df_bicicletas.Intervalo,color='#417DC1', linestyle='-', marker='o',markersize=12,linewidth=5, label='Bicicletas')

#Subte: generación de Lineplot
plt.plot(df_subte.Mes,df_subte.Intervalo,color='#FF8000', linestyle='-.', marker='x',markersize=12,linewidth=5, label='Subte')

#Vehículos:generación de Lineplot
plt.plot(df_vehiculos.Mes,df_vehiculos.Intervalo,color='#04A404', linestyle='--', marker='s',markersize=12,linewidth=5, label='Vehículos')

plt.title("Casos de Covid / Contaminantes / Transporte 2020", fontsize = 20,backgroundcolor="#565656",
  weight="bold",color="white",style="italic",loc="center",pad=30)
plt.xlabel('Mes',weight="bold",size=20,color="#565656")
plt.ylabel('Intervalo',weight="bold",size=20,color="#565656")
plt.tick_params(labelsize=15,length=0)
plt.box(False)
plt.grid(linewidth=0.5,color="grey",linestyle="-.")
plt.legend() #Levanta los labels

plt.show()
