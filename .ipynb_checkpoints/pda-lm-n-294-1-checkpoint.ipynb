# %%
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import pandas as pd
import seaborn as sns

# %%
input_file_name_bicicletas = "https://github.com/fernandorgonzalez/cursos-eant-python_data_analytics-proyecto/blob/main/bicicletas.xlsx?raw=true"
input_sheet_name_bicicletas = "bicicletas"

# %%
input_file_name_contaminantes = "https://github.com/fernandorgonzalez/cursos-eant-python_data_analytics-proyecto/blob/main/contaminantes.xlsx?raw=true"
input_sheet_name_contaminantes = "contaminantes"

# %%
input_file_name_covid = "https://github.com/fernandorgonzalez/cursos-eant-python_data_analytics-proyecto/blob/main/covid.xlsx?raw=true"
input_sheet_name_covid = "covid"

# %%
input_file_name_subte = "https://github.com/fernandorgonzalez/cursos-eant-python_data_analytics-proyecto/blob/main/subte.xlsx?raw=true"
input_sheet_name_subte = "subte"

# %%
input_file_name_vehiculos = "https://github.com/fernandorgonzalez/cursos-eant-python_data_analytics-proyecto/blob/main/vehiculos.xlsx?raw=true"
input_sheet_name_vehiculos = "vehiculos"

# %%
df_bicicletas = pd.read_excel(input_file_name_bicicletas, sheet_name = input_sheet_name_bicicletas)
df_bicicletas
# Out:
#      AÑO  MES        TIPO   TOTAL  INTERVALO DICIEMBRE_ENERO
# 0   2020    1  Bicicletas  159233          5          +100 %
# 1   2020    2  Bicicletas  116965          4          +100 %
# 2   2020    3  Bicicletas   52951          2          +100 %
# 3   2020    4  Bicicletas       0          1          +100 %
# 4   2020    5  Bicicletas   20235          1          +100 %
# 5   2020    6  Bicicletas   69707          3          +100 %
# 6   2020    7  Bicicletas   98328          3          +100 %
# 7   2020    8  Bicicletas  248180          8          +100 %
# 8   2020    9  Bicicletas  273719          9          +100 %
# 9   2020   10  Bicicletas  323130         10          +100 %
# 10  2020   11  Bicicletas  332410         10          +100 %
# 11  2020   12  Bicicletas  308087         10          +100 %

# %%
df_contaminantes = pd.read_excel(input_file_name_contaminantes, sheet_name = input_sheet_name_contaminantes)
df_contaminantes
# Out:
#      AÑO  MES           TIPO      TOTAL  INTERVALO DICIEMBRE_ENERO
# 0   2020    1  Contaminantes  20.648611          6           +33 %
# 1   2020    2  Contaminantes  18.397989          4           +33 %
# 2   2020    3  Contaminantes  17.529570          3           +33 %
# 3   2020    4  Contaminantes  14.089080          1           +33 %
# 4   2020    5  Contaminantes  19.995833          5           +33 %
# 5   2020    6  Contaminantes  17.535920          3           +33 %
# 6   2020    7  Contaminantes  19.442204          5           +33 %
# 7   2020    8  Contaminantes  26.990591         10           +33 %
# 8   2020    9  Contaminantes  20.168056          5           +33 %
# 9   2020   10  Contaminantes  18.970430          4           +33 %
# 10  2020   11  Contaminantes  21.148611          6           +33 %
# 11  2020   12  Contaminantes  24.002778          8           +33 %

# %%
df_covid = pd.read_excel(input_file_name_covid, sheet_name = input_sheet_name_covid)
df_covid
# Out:
#      AÑO  MES            TIPO  TOTAL  INTERVALO DICIEMBRE_ENERO
# 0   2020    1  Casos de Covid     97          1          +900 %
# 1   2020    2  Casos de Covid     30          1          +900 %
# 2   2020    3  Casos de Covid    643          1          +900 %
# 3   2020    4  Casos de Covid   4245          1          +900 %
# 4   2020    5  Casos de Covid  13178          2          +900 %
# 5   2020    6  Casos de Covid  31192          4          +900 %
# 6   2020    7  Casos de Covid  49358          7          +900 %
# 7   2020    8  Casos de Covid  57396          8          +900 %
# 8   2020    9  Casos de Covid  52179          7          +900 %
# 9   2020   10  Casos de Covid  52403          7          +900 %
# 10  2020   11  Casos de Covid  44221          6          +900 %
# 11  2020   12  Casos de Covid  78714         10          +900 %

# %%
df_subte = pd.read_excel(input_file_name_subte, sheet_name = input_sheet_name_subte)
df_subte
# Out:
#      AÑO  MES   TIPO     TOTAL  INTERVALO DICIEMBRE_ENERO
# 0   2020    1  Subte  14431260          9           -77 %
# 1   2020    2  Subte  14379523          9           -77 %
# 2   2020    3  Subte  16665570         10           -77 %
# 3   2020    4  Subte   2532868          1           -77 %
# 4   2020    5  Subte   2769479          1           -77 %
# 5   2020    6  Subte   3566230          1           -77 %
# 6   2020    7  Subte   3417198          1           -77 %
# 7   2020    8  Subte   3122951          1           -77 %
# 8   2020    9  Subte   3629713          1           -77 %
# 9   2020   10  Subte   4966696          2           -77 %
# 10  2020   11  Subte   3768015          1           -77 %
# 11  2020   12  Subte   4255468          2           -77 %

# %%
df_vehiculos = pd.read_excel(input_file_name_vehiculos, sheet_name = input_sheet_name_vehiculos)
df_vehiculos
# Out:
#      AÑO  MES       TIPO   TOTAL  INTERVALO DICIEMBRE_ENERO
# 0   2020    1  Vehículos  248546         10           -10 %
# 1   2020    2  Vehículos  232209          9           -10 %
# 2   2020    3  Vehículos  197980          6           -10 %
# 3   2020    4  Vehículos  143191          1           -10 %
# 4   2020    5  Vehículos  171215          3           -10 %
# 5   2020    6  Vehículos  212227          7           -10 %
# 6   2020    7  Vehículos  209202          7           -10 %
# 7   2020    8  Vehículos  213511          7           -10 %
# 8   2020    9  Vehículos  219852          8           -10 %
# 9   2020   10  Vehículos  226641          8           -10 %
# 10  2020   11  Vehículos  222866          8           -10 %
# 11  2020   12  Vehículos  236303          9           -10 %

# %%
df = pd.concat([df_bicicletas,df_contaminantes,df_covid,df_subte,df_vehiculos])

# %%
df['Diciembre Vs Enero'] = df['TIPO'] + " " + df['DICIEMBRE_ENERO']
df
# Out:
#      AÑO  MES            TIPO         TOTAL  INTERVALO DICIEMBRE_ENERO  \
# 0   2020    1      Bicicletas  1.592330e+05          5          +100 %
# 1   2020    2      Bicicletas  1.169650e+05          4          +100 %
# 2   2020    3      Bicicletas  5.295100e+04          2          +100 %
# 3   2020    4      Bicicletas  0.000000e+00          1          +100 %
# 4   2020    5      Bicicletas  2.023500e+04          1          +100 %
# 5   2020    6      Bicicletas  6.970700e+04          3          +100 %
# 6   2020    7      Bicicletas  9.832800e+04          3          +100 %
# 7   2020    8      Bicicletas  2.481800e+05          8          +100 %
# 8   2020    9      Bicicletas  2.737190e+05          9          +100 %
# 9   2020   10      Bicicletas  3.231300e+05         10          +100 %
# 10  2020   11      Bicicletas  3.324100e+05         10          +100 %
# 11  2020   12      Bicicletas  3.080870e+05         10          +100 %
# 0   2020    1   Contaminantes  2.064861e+01          6           +33 %
# 1   2020    2   Contaminantes  1.839799e+01          4           +33 %
# 0     Contaminantes +33 %
# 1     Contaminantes +33 %
# 2     Contaminantes +33 %
# 3     Contaminantes +33 %
# 4     Contaminantes +33 %
# 5     Contaminantes +33 %
# 6     Contaminantes +33 %
# 7     Contaminantes +33 %
# 8     Contaminantes +33 %
# 9     Contaminantes +33 %
# 10    Contaminantes +33 %
# 11    Contaminantes +33 %
# 0   Casos de Covid +900 %
# 1   Casos de Covid +900 %
# 2   Casos de Covid +900 %
# 3   Casos de Covid +900 %
# 4   Casos de Covid +900 %
# 5   Casos de Covid +900 %
# 6   Casos de Covid +900 %
# 7   Casos de Covid +900 %
# 8   Casos de Covid +900 %
# 9   Casos de Covid +900 %
# 10  Casos de Covid +900 %
# 11  Casos de Covid +900 %
# 0             Subte -77 %
# 1             Subte -77 %
# 2             Subte -77 %
# 3             Subte -77 %
# 4             Subte -77 %
# 5             Subte -77 %
# 6             Subte -77 %
# 7             Subte -77 %
# 8             Subte -77 %
# 9             Subte -77 %
# 10            Subte -77 %
# 11            Subte -77 %
# 0         Vehículos -10 %
# 1         Vehículos -10 %
# 2         Vehículos -10 %
# 3         Vehículos -10 %
# 4         Vehículos -10 %
# 5         Vehículos -10 %
# 6         Vehículos -10 %
# 7         Vehículos -10 %
# 8         Vehículos -10 %
# 9         Vehículos -10 %
# 10        Vehículos -10 %
# 11        Vehículos -10 %

# %%
sns.color_palette('pastel',12)
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353),
#  (0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274)]

# %%
paleta_meses = {}
for i in range(0,12):
    paleta_meses[i+1] = sns.color_palette('pastel',12)[i]
paleta_meses
# Out:
# {1: (0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  2: (1.0, 0.7058823529411765, 0.5098039215686274),
#  3: (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  4: (1.0, 0.6235294117647059, 0.6078431372549019),
#  5: (0.8156862745098039, 0.7333333333333333, 1.0),
#  6: (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  7: (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  8: (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  9: (1.0, 0.996078431372549, 0.6392156862745098),
#  10: (0.7254901960784313, 0.9490196078431372, 0.9411764705882353),
#  11: (0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  12: (1.0, 0.7058823529411765, 0.5098039215686274)}

# %%
paleta_transportes = {}
for i in range(0,len(df['Diciembre Vs Enero'].value_counts().index)):
    paleta_transportes[df['Diciembre Vs Enero'].value_counts().index[i]] = sns.color_palette('pastel',12)[i]
paleta_transportes
# Out:
# {'Contaminantes +33 %': (0.6313725490196078,
#   0.788235294117647,
#   0.9568627450980393),
#  'Vehículos -10 %': (1.0, 0.7058823529411765, 0.5098039215686274),
#  'Casos de Covid +900 %': (0.5529411764705883,
#   0.8980392156862745,
#   0.6313725490196078),
#  'Subte -77 %': (1.0, 0.6235294117647059, 0.6078431372549019),
#  'Bicicletas +100 %': (0.8156862745098039, 0.7333333333333333, 1.0)}

# %%
plt.figure(figsize=(10,7))
s = sns.barplot(data = df_covid,
            x = 'MES',
            y = 'TOTAL',
            palette = paleta_meses)
for p in s.patches:
    s.annotate(int(p.get_height()), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.title("Casos de Covid 2020 (" + df_covid.iloc[0][5] + ")", fontsize = 20)
plt.xlabel('Mes')
plt.ylabel('Total')
plt.show()

# %%
plt.figure(figsize=(10,7))
s = sns.barplot(data = df_contaminantes,
            x = 'MES',
            y = 'TOTAL',
            palette = paleta_meses)
for p in s.patches:
    s.annotate(int(p.get_height()), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.title("Contaminantes 2020 (" + df_contaminantes.iloc[0][5] + ")", fontsize = 20)
plt.xlabel('Mes')
plt.ylabel('Total')
plt.show()

# %%
plt.figure(figsize=(10,7))
s = sns.barplot(data = df_bicicletas,
            x = 'MES',
            y = 'TOTAL',
            palette = paleta_meses)
for p in s.patches:
    s.annotate(str(int(p.get_height()/1000)) + 'K', 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.title("Viajes en Bicicleta 2020 (" + df_bicicletas.iloc[0][5] + ")", fontsize = 20)
plt.xlabel('Mes')
plt.ylabel('Total')
plt.show()

# %%
plt.figure(figsize=(10,7))
s = sns.barplot(data = df_subte,
            x = 'MES',
            y = 'TOTAL',
            palette = paleta_meses)
for p in s.patches:
    s.annotate(str(int(p.get_height()/1000)) + 'K', 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.title("Viajes en Subte 2020 (" + df_subte.iloc[0][5] + ")", fontsize = 20)
plt.xlabel('Mes')
plt.ylabel('Total')
plt.show()

# %%
plt.figure(figsize=(10,7))
s = sns.barplot(data = df_vehiculos,
            x = 'MES',
            y = 'TOTAL',
            palette = paleta_meses)
for p in s.patches:
    s.annotate(str(int(p.get_height()/1000)) + 'K', 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.title("Viajes en Vehículos 2020 (" + df_vehiculos.iloc[0][5] + ")", fontsize = 20)
plt.xlabel('Mes')
plt.ylabel('Total')
plt.show()

# %%
plt.figure(figsize=(13,7))
b = sns.lineplot(data = df,
            x = 'MES',
            y = 'INTERVALO',
            hue = 'Diciembre Vs Enero',
            hue_order = ['Casos de Covid ' + df_covid.iloc[0][5], 'Contaminantes ' + df_contaminantes.iloc[0][5],'Bicicletas ' + df_bicicletas.iloc[0][5],'Subte ' + df_subte.iloc[0][5],'Vehículos ' + df_vehiculos.iloc[0][5]],
            style = 'Diciembre Vs Enero',
            markers=True,
            dashes=True,
            palette = paleta_transportes)
plt.title("Casos de Covid Vs Transporte 2020", fontsize = 20)
plt.xlabel('Mes')
plt.ylabel('Intervalo')
plt.show()
